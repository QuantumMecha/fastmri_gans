# %%
# Mount the Google Drive so we can access data
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !wget -P /content/drive/My\ Drive/CS7643_Project/Data/raw https://fastmri-dataset.s3.amazonaws.com/SHA256?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA&Signature=rMPn9iyl1E1rgEd82voNuypLvvs%3D&Expires=1642530569
# !wget -P /content/drive/My\ Drive/CS7643_Project/Data/raw https://fastmri-dataset.s3.amazonaws.com/brain_multicoil_challenge.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA&Signature=OcDRREzFlaHWZX8UCJuDGpsKyOQ%3D&Expires=1642530569
# !wget -P /content/drive/My\ Drive/CS7643_Project/Data/raw https://fastmri-dataset.s3.amazonaws.com/brain_multicoil_challenge_transfer.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA&Signature=9ND99tcdhsfVmMkvYyZZ4PZZAK8%3D&Expires=1642530569
# !wget -P /content/drive/My\ Drive/CS7643_Project/Data/raw https://fastmri-dataset.s3.amazonaws.com/brain_multicoil_train.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA&Signature=eCrNn0AVT%2Fx%2FmVVoSQN5i3MkaVI%3D&Expires=1642530569
# !wget -P /content/drive/My\ Drive/CS7643_Project/Data/raw https://fastmri-dataset.s3.amazonaws.com/brain_multicoil_val.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA&Signature=dhjexw7irPrmdoY%2BqsngQq8UCac%3D&Expires=1642530569
# !wget -P /content/drive/My\ Drive/CS7643_Project/Data/raw https://fastmri-dataset.s3.amazonaws.com/brain_multicoil_test.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA&Signature=qJMcjigAHEw6Nn2CYiebesiZRG0%3D&Expires=1642530569
# !wget -P /content/drive/My\ Drive/CS7643_Project/Data/raw https://fastmri-dataset.s3.amazonaws.com/brain_fastMRI_DICOM.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA&Signature=hG7HSMKApu0qAG0W1lv673ZBD%2F0%3D&Expires=1642530569
# Out:
# --2021-10-31 20:19:33--  https://fastmri-dataset.s3.amazonaws.com/SHA256?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA
# Resolving fastmri-dataset.s3.amazonaws.com (fastmri-dataset.s3.amazonaws.com)... 52.217.93.124
# Connecting to fastmri-dataset.s3.amazonaws.com (fastmri-dataset.s3.amazonaws.com)|52.217.93.124|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1588 (1.6K) [binary/octet-stream]
# Saving to: ‘/content/drive/My Drive/CS7643_Project/Data/raw/SHA256?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA.1’
#
# SHA256?AWSAccessKey 100%[===================>]   1.55K  --.-KB/s    in 0s
#
# 2021-10-31 20:19:33 (42.5 MB/s) - ‘/content/drive/My Drive/CS7643_Project/Data/raw/SHA256?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA.1’ saved [1588/1588]
#
# --2021-10-31 20:19:33--  https://fastmri-dataset.s3.amazonaws.com/brain_multicoil_challenge.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA
# Resolving fastmri-dataset.s3.amazonaws.com (fastmri-dataset.s3.amazonaws.com)... 52.217.93.124
# Connecting to fastmri-dataset.s3.amazonaws.com (fastmri-dataset.s3.amazonaws.com)|52.217.93.124|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39143430645 (36G) [application/x-tar]
# Saving to: ‘/content/drive/My Drive/CS7643_Project/Data/raw/brain_multicoil_challenge.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA’
#
# brain_multicoil_cha 100%[===================>]  36.46G  45.8MB/s    in 14m 28s
#
# 2021-10-31 20:34:01 (43.0 MB/s) - ‘/content/drive/My Drive/CS7643_Project/Data/raw/brain_multicoil_challenge.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA’ saved [39143430645/39143430645]
#
# --2021-10-31 20:34:01--  https://fastmri-dataset.s3.amazonaws.com/brain_multicoil_challenge_transfer.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA
# Resolving fastmri-dataset.s3.amazonaws.com (fastmri-dataset.s3.amazonaws.com)... 54.231.130.49
# Connecting to fastmri-dataset.s3.amazonaws.com (fastmri-dataset.s3.amazonaws.com)|54.231.130.49|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20499723261 (19G) [application/x-tar]
# Saving to: ‘/content/drive/My Drive/CS7643_Project/Data/raw/brain_multicoil_challenge_transfer.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA’
#
# brain_multicoil_cha 100%[===================>]  19.09G  42.1MB/s    in 13m 46s
#
# 2021-10-31 20:47:48 (23.7 MB/s) - ‘/content/drive/My Drive/CS7643_Project/Data/raw/brain_multicoil_challenge_transfer.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA’ saved [20499723261/20499723261]
#
# --2021-10-31 20:47:48--  https://fastmri-dataset.s3.amazonaws.com/brain_multicoil_train.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA
# Resolving fastmri-dataset.s3.amazonaws.com (fastmri-dataset.s3.amazonaws.com)... 52.217.83.52
# Connecting to fastmri-dataset.s3.amazonaws.com (fastmri-dataset.s3.amazonaws.com)|52.217.83.52|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1293335773700 (1.2T) [application/x-tar]
# Saving to: ‘/content/drive/My Drive/CS7643_Project/Data/raw/brain_multicoil_train.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA’
#
# brain_multicoil_tra   5%[>                   ]  60.90G  56.2MB/s    in 26m 45s
#
#
# Cannot write to ‘/content/drive/My Drive/CS7643_Project/Data/raw/brain_multicoil_train.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA’ (Success).
# --2021-10-31 21:14:33--  https://fastmri-dataset.s3.amazonaws.com/brain_multicoil_val.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA
# Resolving fastmri-dataset.s3.amazonaws.com (fastmri-dataset.s3.amazonaws.com)... 52.217.139.57
# Connecting to fastmri-dataset.s3.amazonaws.com (fastmri-dataset.s3.amazonaws.com)|52.217.139.57|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 376783034062 (351G) [application/x-tar]
# Saving to: ‘/content/drive/My Drive/CS7643_Project/Data/raw/brain_multicoil_val.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA’
#
# brain_multicoil_val  17%[==>                 ]  60.90G  53.3MB/s    in 19m 55s
#
#
# Cannot write to ‘/content/drive/My Drive/CS7643_Project/Data/raw/brain_multicoil_val.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA’ (Success).
# --2021-10-31 21:34:29--  https://fastmri-dataset.s3.amazonaws.com/brain_multicoil_test.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA
# Resolving fastmri-dataset.s3.amazonaws.com (fastmri-dataset.s3.amazonaws.com)... 52.216.86.67
# Connecting to fastmri-dataset.s3.amazonaws.com (fastmri-dataset.s3.amazonaws.com)|52.216.86.67|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36678283405 (34G) [application/x-tar]
# Saving to: ‘/content/drive/My Drive/CS7643_Project/Data/raw/brain_multicoil_test.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA’
#
# brain_multicoil_tes 100%[===================>]  34.16G  49.1MB/s    in 12m 17s
#
# 2021-10-31 21:46:48 (47.5 MB/s) - ‘/content/drive/My Drive/CS7643_Project/Data/raw/brain_multicoil_test.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA’ saved [36678283405/36678283405]
#
# --2021-10-31 21:46:48--  https://fastmri-dataset.s3.amazonaws.com/brain_fastMRI_DICOM.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA
# Resolving fastmri-dataset.s3.amazonaws.com (fastmri-dataset.s3.amazonaws.com)... 54.231.49.218
# Connecting to fastmri-dataset.s3.amazonaws.com (fastmri-dataset.s3.amazonaws.com)|54.231.49.218|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 42481326351 (40G) [application/x-gzip]
# Saving to: ‘/content/drive/My Drive/CS7643_Project/Data/raw/brain_fastMRI_DICOM.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA’
#
# brain_fastMRI_DICOM 100%[===================>]  39.56G  53.5MB/s    in 21m 19s
#
# 2021-10-31 22:08:07 (31.7 MB/s) - ‘/content/drive/My Drive/CS7643_Project/Data/raw/brain_fastMRI_DICOM.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA’ saved [42481326351/42481326351]
