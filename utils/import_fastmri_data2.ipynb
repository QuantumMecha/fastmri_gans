# %%
# Mount the Google Drive so we can access data
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# https://fastmri-dataset.s3.amazonaws.com/SHA256
# !wget -P /content/drive/My\ Drive/CS7643_Project/Data/raw https://fastmri-dataset.s3.amazonaws.com/SHA256?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA&Signature=rMPn9iyl1E1rgEd82voNuypLvvs%3D&Expires=1642530569
# Out:
# --2021-10-31 20:15:01--  https://fastmri-dataset.s3.amazonaws.com/SHA256?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA
# Resolving fastmri-dataset.s3.amazonaws.com (fastmri-dataset.s3.amazonaws.com)... 52.217.94.92
# Connecting to fastmri-dataset.s3.amazonaws.com (fastmri-dataset.s3.amazonaws.com)|52.217.94.92|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1588 (1.6K) [binary/octet-stream]
# Saving to: ‘/content/drive/My Drive/CS7643_Project/Data/raw/SHA256?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA’
#
# SHA256?AWSAccessKey 100%[===================>]   1.55K  --.-KB/s    in 0.001s
#
# 2021-10-31 20:15:01 (1.39 MB/s) - ‘/content/drive/My Drive/CS7643_Project/Data/raw/SHA256?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA’ saved [1588/1588]

# %%
# https://fastmri-dataset.s3.amazonaws.com/brain_multicoil_challenge.tar.gz
# !wget -P /content/drive/My\ Drive/CS7643_Project/Data/raw https://fastmri-dataset.s3.amazonaws.com/brain_multicoil_challenge.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA&Signature=OcDRREzFlaHWZX8UCJuDGpsKyOQ%3D&Expires=1642530569
# Out:
# --2021-10-31 20:37:53--  https://fastmri-dataset.s3.amazonaws.com/brain_multicoil_challenge.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA
# Resolving fastmri-dataset.s3.amazonaws.com (fastmri-dataset.s3.amazonaws.com)... 52.217.33.116
# Connecting to fastmri-dataset.s3.amazonaws.com (fastmri-dataset.s3.amazonaws.com)|52.217.33.116|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39143430645 (36G) [application/x-tar]
# Saving to: ‘/content/drive/My Drive/CS7643_Project/Data/raw/brain_multicoil_challenge.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA’
#
# brain_multicoil_cha 100%[===================>]  36.46G  42.4MB/s    in 13m 7s
#
# 2021-10-31 20:51:01 (47.4 MB/s) - ‘/content/drive/My Drive/CS7643_Project/Data/raw/brain_multicoil_challenge.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA’ saved [39143430645/39143430645]

# %%
# https://fastmri-dataset.s3.amazonaws.com/brain_multicoil_challenge_transfer.tar.gz
# !wget -P /content/drive/My\ Drive/CS7643_Project/Data/raw https://fastmri-dataset.s3.amazonaws.com/brain_multicoil_challenge_transfer.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA&Signature=9ND99tcdhsfVmMkvYyZZ4PZZAK8%3D&Expires=1642530569

# %%
# https://fastmri-dataset.s3.amazonaws.com/brain_multicoil_train.tar.gz
# !wget -P /content/drive/My\ Drive/CS7643_Project/Data/raw https://fastmri-dataset.s3.amazonaws.com/brain_multicoil_train.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA&Signature=eCrNn0AVT%2Fx%2FmVVoSQN5i3MkaVI%3D&Expires=1642530569
# Out:
# --2021-10-31 23:01:53--  https://fastmri-dataset.s3.amazonaws.com/brain_multicoil_train.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA
# Resolving fastmri-dataset.s3.amazonaws.com (fastmri-dataset.s3.amazonaws.com)... 52.216.251.28
# Connecting to fastmri-dataset.s3.amazonaws.com (fastmri-dataset.s3.amazonaws.com)|52.216.251.28|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1293335773700 (1.2T) [application/x-tar]
# Saving to: ‘/content/drive/My Drive/CS7643_Project/Data/raw/brain_multicoil_train.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA.1’
#
# brain_multicoil_tra  14%[=>                  ] 178.99G  16.0MB/s    in 3h 16m
#
#
# Cannot write to ‘/content/drive/My Drive/CS7643_Project/Data/raw/brain_multicoil_train.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA.1’ (Success).

# %%
# https://fastmri-dataset.s3.amazonaws.com/brain_multicoil_val.tar.gz
# !wget -P /content/drive/My\ Drive/CS7643_Project/Data/raw https://fastmri-dataset.s3.amazonaws.com/brain_multicoil_val.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA&Signature=dhjexw7irPrmdoY%2BqsngQq8UCac%3D&Expires=1642530569
# Out:
# --2021-11-01 02:18:28--  https://fastmri-dataset.s3.amazonaws.com/brain_multicoil_val.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA
# Resolving fastmri-dataset.s3.amazonaws.com (fastmri-dataset.s3.amazonaws.com)... 52.217.207.9
# Connecting to fastmri-dataset.s3.amazonaws.com (fastmri-dataset.s3.amazonaws.com)|52.217.207.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 376783034062 (351G) [application/x-tar]
# Saving to: ‘/content/drive/My Drive/CS7643_Project/Data/raw/brain_multicoil_val.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA.1’
#
# brain_multicoil_val  51%[=========>          ] 178.99G  16.1MB/s    in 3h 15m
#
#
# Cannot write to ‘/content/drive/My Drive/CS7643_Project/Data/raw/brain_multicoil_val.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA.1’ (Success).

# %%
# https://fastmri-dataset.s3.amazonaws.com/brain_multicoil_test.tar.gz
# !wget -P /content/drive/My\ Drive/CS7643_Project/Data/raw https://fastmri-dataset.s3.amazonaws.com/brain_multicoil_test.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA&Signature=qJMcjigAHEw6Nn2CYiebesiZRG0%3D&Expires=1642530569

# %%
# https://fastmri-dataset.s3.amazonaws.com/brain_fastMRI_DICOM.tar.gz
# !wget -P /content/drive/My\ Drive/CS7643_Project/Data/raw https://fastmri-dataset.s3.amazonaws.com/brain_fastMRI_DICOM.tar.gz?AWSAccessKeyId=AKIAJM2LEZ67Y2JL3KRA&Signature=hG7HSMKApu0qAG0W1lv673ZBD%2F0%3D&Expires=1642530569
